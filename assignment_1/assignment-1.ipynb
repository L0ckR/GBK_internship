# %% [markdown]
# # Задание 1

# %% [markdown]
# Каждая строчка датасета - пост из твиттера, два класса: катастрофа и нет
# 1. Необходимо очистить данные от лишних символов и стоп-слов.
# 2. Построить информативные графики, демонстрирующие специфику датасета.
# 3. Применить 3 способа токенизации (по словам, bpe, berttokenizer)
# 4. Сделать одну векторизацию и 2 варианта эмбеддингов. Один из алгоритмов эмбеддингов предобученная модель (huggingface).
# 5. Визуализировать близость получившихся эмбеддингов, цветами окрасить разные классы. Можно применить PCA перед отрисовкой
# 6. Для каждой используемой технологии в комментариях около ячейки с кодом написать своими словами принцип (идею) алгоритма. Описания похожие на текст от GPT приниматься не будут.
# 7. Выложить на github

# %% [markdown]
# ## Описание и первичное изучение

# %% [markdown]
# Импортируем необходимые для дальнейшей работы библиотеки

# %%
# %pip install langid pandas nltk seaborn matplotlib sentencepiece

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
import seaborn as sns
import langid
import nltk
import re
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langid in /home/lockr/.local/lib/python3.10/site-packages (1.1.6)
# Requirement already satisfied: pandas in /home/lockr/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: nltk in /home/lockr/.local/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: seaborn in /home/lockr/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: sentencepiece in /home/lockr/.local/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: numpy in /home/lockr/.local/lib/python3.10/site-packages (from langid) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/lockr/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lockr/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/lockr/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tqdm in /home/lockr/.local/lib/python3.10/site-packages (from nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/lockr/.local/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: joblib in /home/lockr/.local/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: click in /home/lockr/.local/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: packaging>=20.0 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: pillow>=8 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: six>=1.5 in /home/lockr/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Прочитаем файл датасета в pandas датафрейм

# %%
df = pd.read_csv('socialmedia_relevant_cols.csv', encoding='unicode_escape')
df.head()
# Out:
#                                                 text choose_one  class_label
# 0                 Just happened a terrible car crash   Relevant            1
# 1  Our Deeds are the Reason of this #earthquake M...   Relevant            1
# 2  Heard about #earthquake is different cities, s...   Relevant            1
# 3  there is a forest fire at spot pond, geese are...   Relevant            1
# 4             Forest fire near La Ronge Sask. Canada   Relevant            1

# %% [markdown]
# Добавим столбец с длинной каждого твита и рассмотрим его

# %%
df["text_length"] = df["text"].apply(lambda x : len(x))

print("Train Length Stat")
print(df["text_length"].describe())
# Out:
# Train Length Stat
# count    10876.000000
# mean       101.725634
# std         34.118877
# min          5.000000
# 25%         78.000000
# 50%        108.000000
# 75%        134.000000
# max        168.000000
# Name: text_length, dtype: float64

# %% [markdown]
# Проанализируем язык твитов в датасете \
# Т.к. nlkt.TextCat() использует в себе анализ n-грам, получается, что он намного эффективнее работает на коротких сообщениях по сравнению с langid. Но на длинных текстах он становится чересчур сложным и в разы дольше работает. Поэтому в идеале можно применять для коротких текстов nlkt, а для длинных langid или комбинировать их.

# %%
from nltk.classify.textcat import TextCat # language identification from NLTK
nltk.download('crubadan')
nltk.download('punkt')
tc = TextCat()
langid_guess = df['text'].apply(langid.classify)
tc_guess = df['text'][0:50].apply(tc.guess_language)
# Out:
# [nltk_data] Downloading package crubadan to /home/lockr/nltk_data...
# [nltk_data]   Package crubadan is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lockr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Возьмем для этого алгоритма только первые 50, т.к. он очень ресурсозатратный

# %%
df[0:50][tc_guess.apply(lambda x: x!='eng')]
# Out:
#                                                  text    choose_one  \
# 6   13,000 people receive #wildfires evacuation or...      Relevant
# 11      Typhoon Soudelor kills 28 in China and Taiwan      Relevant
# 14  There's an emergency evacuation happening now ...      Relevant
# 19            #Flood in Bago Myanmar #We arrived Bago      Relevant
# 20  Damage to school bus on 80 in multi car crash ...      Relevant
# 28                       What a goooooooaaaaaal!!!!!!  Not Relevant
# 29                                          Fuck off!  Not Relevant
# 31                             this is ridiculous....  Not Relevant
# 33                                        Love skiing  Not Relevant
# 36                                           LOOOOOOL  Not Relevant
# 40                                          Cooool :)  Not Relevant
# 41                                 Do you like pasta?  Not Relevant
# 45                                           Awesome!  Not Relevant
#
#     class_label  text_length
# 6             1           65
# 11            1           45
# 14            1           79
# 19            1           39
# 20            1           56
# 28            0           28
# 29            0            9
# 31            0           22
# 33            0           11
# 36            0            8
# 40            0            9
# 41            0           18
# 45            0            8

# %% [markdown]
# В нашем случае можно заметить, что все твиты, даже ошибочно признанные не английским - все-таки написаны на английском языке.

# %%
df[0:50][langid_guess[0:50].apply(lambda x: x[0]!='en')]
# Out:
#                                                  text    choose_one  \
# 4              Forest fire near La Ronge Sask. Canada      Relevant
# 18  #raining #flooding #Florida #TampaBay #Tampa 1...      Relevant
# 24                                      I love fruits  Not Relevant
# 33                                        Love skiing  Not Relevant
# 41                                 Do you like pasta?  Not Relevant
#
#     class_label  text_length
# 4             1           38
# 18            1           76
# 24            0           13
# 33            0           11
# 41            0           18

# %% [markdown]
# ## Предобработка

# %% [markdown]
# Создадим колонку, в которой будет обрабатывать текст

# %%
df['cleaned_text'] = df['text'].copy()

# %% [markdown]
# Избавимся от остатков юникода

# %%
df['cleaned_text'] = df['cleaned_text'].apply(lambda x :x.encode("utf8").decode("utf8"))

# %% [markdown]
# Удалим ссылки из данных

# %%
def remove_url(text):
    return re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", text)

df['cleaned_text'] = df['cleaned_text'].apply(remove_url)
print(df.text[10871], df.class_label[10871])
# Out:
# M1.94 [01:04 UTC]?5km S of Volcano Hawaii. http://t.co/zDtoyd8EbJ 1

# %% [markdown]
# Далее делом удалим знаки препинания и хэштеги
#
# прощайте текстовые смайлики :(

# %%
import string
def removing_symbols(text):
    symbols = string.punctuation + string.digits
    return text.translate(str.maketrans('', '', symbols))

df["cleaned_text"] = df["cleaned_text"].apply(removing_symbols)

# %% [markdown]
# Также избавимся от stop-слов, их возьмем из библиотеки sklearn(для сравнения приведены размеры словаря в nltk и sklearn)

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from nltk.corpus import stopwords


nltk.download('stopwords')
print(len(set(stopwords.words('english'))), len(ENGLISH_STOP_WORDS))
# Out:
# 179 318
# [nltk_data] Downloading package stopwords to /home/lockr/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Применим к текстам функцию, которая удаляет стоп-слова из предложений

# %%
import re

def removing_sw(text):
    return " ".join([word for word in re.split("\W+",text) if word.lower() not in ENGLISH_STOP_WORDS])

df['cleaned_text'] = df['cleaned_text'].apply(removing_sw)

# %% [markdown]
# Леммматизируем слова(приведем к одной форме слова)

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize


nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

df['cleaned_text'] = df['cleaned_text'].apply(lambda x: " ".join(list(map(lemmatizer.lemmatize, word_tokenize(x)))))
# Out:
# [nltk_data] Downloading package wordnet to /home/lockr/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Удалим повторяющиеся(больше 3х) буквы

# %%
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: re.sub(r"(.)\1\1+",r'\1\1', x).replace('\n', ' '))

# %% [markdown]
# Избавимся от верхнего регистра и запишем длину новых текстов в отдельный столбец

# %%
df['cleaned_text'] = df['cleaned_text'].apply(str.lower)
df['cleaned_text_length'] = df["cleaned_text"].apply(lambda x : len(x))
df['cleaned_text_length'].describe()
# Out:
# count    10876.000000
# mean        60.807374
# std         23.875280
# min          0.000000
# 25%         43.000000
# 50%         62.000000
# 75%         79.000000
# max        138.000000
# Name: cleaned_text_length, dtype: float64

# %% [markdown]
# Удлим NaN, дубликаты и неразмеченные данные, а также обновим индексацию

# %%
df.dropna(inplace=True)
df.drop_duplicates(subset="text",inplace=True)
df.drop_duplicates(subset="cleaned_text",inplace=True)
df = df[~(df['class_label'] == 2)]
df.reset_index(inplace=True)
df.drop(columns=['index'], inplace=True)

# %%
df.head()
# Out:
#                                                 text choose_one  class_label  \
# 0                 Just happened a terrible car crash   Relevant            1
# 1  Our Deeds are the Reason of this #earthquake M...   Relevant            1
# 2  Heard about #earthquake is different cities, s...   Relevant            1
# 3  there is a forest fire at spot pond, geese are...   Relevant            1
# 4             Forest fire near La Ronge Sask. Canada   Relevant            1
#
#    text_length                                cleaned_text  \
# 0           34            just happened terrible car crash
# 1           69       deeds reason earthquake allah forgive
# 2           64   heard earthquake different city stay safe
# 3           96  forest spot pond goose fleeing street save
# 4           38            forest near la ronge sask canada
#
#    cleaned_text_length
# 0                   32
# 1                   37
# 2                   41
# 3                   42
# 4                   32

# %%
df['cleaned_text'].describe()
# Out:
# count                                 9626
# unique                                9626
# top       just happened terrible car crash
# freq                                     1
# Name: cleaned_text, dtype: object

# %% [markdown]
# ## Графики

# %% [markdown]
# Рассмотрим распределение классов

# %%
def count_table(df, c):
        count = df[c].value_counts()
        count_percent = 100 * count / len(df)
        count_table = pd.concat([count, count_percent], axis=1)
        
        count_table.columns = [c, '% of Count']
        count_table.round(2)

        gb = df.groupby(df[c])
        targetEDA=gb[c].aggregate(len)
        
        plt.figure()
        targetEDA.plot(kind='bar', grid=False)
        plt.axhline(0, color='k')
        
        return count_table

count_table(df, 'choose_one')
# Out:
#               choose_one  % of Count
# choose_one
# Not Relevant        5687   59.079576
# Relevant            3939   40.920424

# %% [markdown]
# Воспользуемся pyplot'ером для визуализации изменения длины текстов после очистки

# %%
# Make a separate list for each airline
x1 = sorted(list(df['text_length']))
x2 = sorted(list(df['cleaned_text_length']))

# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9']
names = ['Original', 'Cleaned']

# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.plot(x1, color = colors[0], label=names[0])
plt.plot(x2, color = colors[1], label=names[1])
# Plot formatting
plt.legend()
plt.xlabel('Tweets')
plt.ylabel('Length')
plt.title('Length diff')
# Out:
# Text(0.5, 1.0, 'Length diff')

# %% [markdown]
# ## Токенизация

# %% [markdown]
# ### Word Tokenize

# %% [markdown]
# Одним из самых очевидных способов токенизации является разделение корпуса текста на слова

# %%
import nltk
from nltk.tokenize import WordPunctTokenizer

word_tokenizer = WordPunctTokenizer()
nltk.download('punkt')

df['word_tokens'] = df['cleaned_text'].apply(word_tokenizer.tokenize)
df[['word_tokens']]
# Out:
# 5
# [nltk_data] Downloading package punkt to /home/lockr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                             word_tokens
# 0                [just, happened, terrible, car, crash]
# 1           [deeds, reason, earthquake, allah, forgive]
# 2      [heard, earthquake, different, city, stay, safe]
# 3     [forest, spot, pond, goose, fleeing, street, s...
# 4               [forest, near, la, ronge, sask, canada]
# ...                                                 ...
# 9621  [officials, say, quarantine, place, alabama, h...
# 9622  [flip, im, walmart, bomb, evacuate, stay, tune...
# 9623  [suicide, bomber, kill, saudi, security, site,...
# 9624                 [green, line, derailment, chicago]
# 9625  [cityofcalgary, activated, municipal, emergenc...
#
# [9626 rows x 1 columns]

# %% [markdown]
# Еще нашел токенайзер, который заточен под работу с твитами. Достойно упоминания, т.к. хорошо подходит для работы с твиттерской лексикой

# %%
from nltk.tokenize import TweetTokenizer

tknzr = TweetTokenizer(reduce_len=True, preserve_case=False, strip_handles=True)

df['tw_tokens'] = df['text'].apply(tknzr.tokenize)
df[['tw_tokens']]
# Out:
#                                               tw_tokens
# 0             [just, happened, a, terrible, car, crash]
# 1     [our, deeds, are, the, reason, of, this, #eart...
# 2     [heard, about, #earthquake, is, different, cit...
# 3     [there, is, a, forest, fire, at, spot, pond, ,...
# 4      [forest, fire, near, la, ronge, sask, ., canada]
# ...                                                 ...
# 9621  [officials, say, a, quarantine, is, in, place,...
# 9622  [on, the, flip, side, i'm, at, walmart, and, t...
# 9623  [suicide, bomber, kills, 15, in, saudi, securi...
# 9624  [green, line, derailment, in, chicago, http://...
# 9625  [#cityofcalgary, has, activated, its, municipa...
#
# [9626 rows x 1 columns]

# %% [markdown]
# ### BPE

# %% [markdown]
# Byte-pair-encoding тренируется и ищет часто встречаемые сочетания букв(части слов) и использует их в качестве токенов \
# Импортируем библиотеки для тренировки собственного BPE

# %%
from tokenizers import (
    decoders,
    models,
    normalizers,
    pre_tokenizers,
    processors,
    trainers,
    Tokenizer,
)
from transformers import PreTrainedTokenizerFast

# %% [markdown]
# Создадим объект токенайзера и определим поведение для его нормализатора и пре-токенайзера

# %%
raw_tokenizer = Tokenizer(models.BPE(unk_token="[UNK]"))
raw_tokenizer.normalizer = normalizers.Sequence([normalizers.NFC()])
raw_tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel()

# %% [markdown]
# Опредленным специальные символы, которые могут быть использованы в качестве части токена

# %%
special_tokens = ["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]"]
trainer = trainers.BpeTrainer(vocab_size=30522, special_tokens=special_tokens)

# %% [markdown]
# Натренируем на имеющемся датасете

# %%
dataset = df.copy()
def train_corp_iter():
    for i in range(0, len(dataset), 1000):
        yield dataset[i : i + 1000]["cleaned_text"]
raw_tokenizer.train_from_iterator(train_corp_iter(), trainer=trainer)

# %% [markdown]
# Создадим окончательный объект токенайзера, предобученный на наших данных

# %%
tokenizer = PreTrainedTokenizerFast(
    tokenizer_object=raw_tokenizer,
    unk_token="[UNK]",
    pad_token="[PAD]",
    cls_token="[CLS]",
    sep_token="[SEP]",
    mask_token="[MASK]",
)

# %% [markdown]
# И применим к текстам

# %%
df['bpe_tokens'] = df['cleaned_text'].apply(tokenizer.tokenize)
df[['bpe_tokens']]
# Out:
#                                              bpe_tokens
# 0           [Ġjust, Ġhappened, Ġterrible, Ġcar, Ġcrash]
# 1      [Ġdeeds, Ġreason, Ġearthquake, Ġallah, Ġforgive]
# 2     [Ġheard, Ġearthquake, Ġdifferent, Ġcity, Ġstay...
# 3     [Ġforest, Ġspot, Ġpond, Ġgoose, Ġfleeing, Ġstr...
# 4         [Ġforest, Ġnear, Ġla, Ġronge, Ġsask, Ġcanada]
# ...                                                 ...
# 9621  [Ġofficials, Ġsay, Ġquarantine, Ġplace, Ġalaba...
# 9622  [Ġflip, Ġim, Ġwalmart, Ġbomb, Ġevacuate, Ġstay...
# 9623  [Ġsuicide, Ġbomber, Ġkill, Ġsaudi, Ġsecurity, ...
# 9624             [Ġgreen, Ġline, Ġderailment, Ġchicago]
# 9625  [Ġcityofcalgary, Ġactivated, Ġmunicipal, Ġemer...
#
# [9626 rows x 1 columns]

# %% [markdown]
# ### BertTokenizer

# %% [markdown]
# Импортируем бибилиотеку для использования модели BertTokenizer и скачаем из интернета предобученную версию, хатем применим на наших текстах

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

df['bert_tokens'] = df['cleaned_text'].apply(tokenizer.tokenize)
df[['bert_tokens']]
# Out:
#                                             bert_tokens
# 0                [just, happened, terrible, car, crash]
# 1           [deeds, reason, earthquake, allah, forgive]
# 2      [heard, earthquake, different, city, stay, safe]
# 3     [forest, spot, pond, goose, fleeing, street, s...
# 4       [forest, near, la, ron, ##ge, sas, ##k, canada]
# ...                                                 ...
# 9621  [officials, say, qu, ##aran, ##tine, place, al...
# 9622  [flip, im, wal, ##mart, bomb, evacuate, stay, ...
# 9623  [suicide, bomber, kill, saudi, security, site,...
# 9624         [green, line, der, ##ail, ##ment, chicago]
# 9625  [city, ##of, ##cal, ##gar, ##y, activated, mun...
#
# [9626 rows x 1 columns]

# %% [markdown]
# ## Векторизация

# %% [markdown]
# ### TF*IDF

# %% [markdown]
# Импортируем необходимые библиотеки для векторизации с помощью TF*IDF, а также алгоритмы поиска главных компонент, уменьшения размерности и визуализации

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# %pip install yellowbrick
from sklearn.decomposition import PCA, TruncatedSVD
from yellowbrick.text import TSNEVisualizer
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yellowbrick in /home/lockr/.local/lib/python3.10/site-packages (1.5)
# Requirement already satisfied: scipy>=1.0.0 in /home/lockr/.local/lib/python3.10/site-packages (from yellowbrick) (1.13.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from yellowbrick) (3.9.1)
# Requirement already satisfied: cycler>=0.10.0 in /home/lockr/.local/lib/python3.10/site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/lockr/.local/lib/python3.10/site-packages (from yellowbrick) (1.4.2)
# Requirement already satisfied: numpy>=1.16.0 in /home/lockr/.local/lib/python3.10/site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.0)
# Requirement already satisfied: pillow>=8 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lockr/.local/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/lockr/.local/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/lockr/.local/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/lockr/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Применим алгоритм впкторизации к нашим данным и визуализируем с помощью TSNE

# %%
def tfidf(data):
    tfidf_vectorizer = TfidfVectorizer()
    train = tfidf_vectorizer.fit_transform(data)
    return train, tfidf_vectorizer

X, tfidf_vectorizer = tfidf(df["cleaned_text"])

y = df.class_label

visualizer = TSNEVisualizer()
visualizer.fit_transform(X, y)
visualizer.show()
# Out:
# /home/lockr/.local/lib/python3.10/site-packages/yellowbrick/text/tsne.py:401: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   self.ax.scatter(
# <Axes: title={'center': 'TSNE Projection of 9626 Documents'}>

# %% [markdown]
# Создадим функцию для разметки данных в двух измерениях, применим алгоритм редукции размерности и глянем на результат

# %%
def scatter(y_train, lsa_scores):
    colors = ['blue','green']

    plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=18, alpha=.8, c=y_train, cmap=matplotlib.colors.ListedColormap(colors))
    
    blue_patch = mpatches.Patch(color='blue', label='Disaster')
    green_patch = mpatches.Patch(color='green', label='Irrelevant')
    plt.legend(handles=[blue_patch, green_patch], prop={'size': 20})


svd = TruncatedSVD(n_components=2)
lsa_tfidf = svd.fit_transform(X, y)
               
fig = plt.figure(figsize=(10, 10))         
scatter(y, lsa_tfidf)
plt.show()

# %% [markdown]
# ## Эмбеддинги

# %% [markdown]
# ### Word2Vec

# %% [markdown]
# Скачаем моудль Gensim

# %%
# %pip install gensim
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /home/lockr/.local/lib/python3.10/site-packages (4.3.3)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /home/lockr/.local/lib/python3.10/site-packages (from gensim) (1.13.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/lockr/.local/lib/python3.10/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /home/lockr/.local/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: wrapt in /home/lockr/.local/lib/python3.10/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Создадим функцию для суммаризации векторов тоекнов в одном тексте и фнукцию создания эмбеддингов на ее основе

# %%
def get_average_word2vec(tokens_list, vector, generate_missing=False, k=300):
    if len(tokens_list)<1:
        return np.zeros(k)
    if generate_missing:
        vectorized = [vector[word] if word in vector else np.random.rand(k) for word in tokens_list]
    else:
        vectorized = [vector[word] if word in vector else np.zeros(k) for word in tokens_list]
        
    length = len(vectorized)
    summed = np.sum(vectorized, axis=0)
    averaged = np.divide(summed, length)
    return averaged

# %%
def get_word2vec_embeddings(vectors, data, generate_missing=False, k=300):
    embeddings = data['word_tokens'].apply(lambda x: get_average_word2vec(x, vectors, generate_missing=generate_missing, k=k))
    return list(embeddings)

# %% [markdown]
# Создадим объект модели word2vec и обучим на наших данных

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec(df['word_tokens'])

# %% [markdown]
# получим эмбеддинги этой модели

# %%
our_wv_embd = get_word2vec_embeddings(model.wv, df, k=100)
our_wv_embd = np.array(our_wv_embd)

# %% [markdown]
# Проанализируем и построим график по полученным эмбеддингам(а точнее по первым двум признакам из них)

# %%
fig = plt.figure(figsize=(8, 6))         
scatter(y, our_wv_embd)
plt.show()

# %% [markdown]
# Редуцируем размерность векторов эмбеддирнгов и получим новый график, где данные уже явнее классифицированы

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(our_wv_embd, df['class_label'])
color_mapper = {label:idx for idx, label in enumerate(set(y))}
color_column = [color_mapper[label] for label in y]
colors = ['pink','blue']


plt.scatter(pca_result[:, 0], pca_result[:, 1], s=8, alpha=.8, c=y, cmap=matplotlib.colors.ListedColormap(colors))
red_patch = mpatches.Patch(color='pink', label='Irrelevant')
green_patch = mpatches.Patch(color='blue', label='Disaster')
plt.legend(handles=[red_patch, green_patch], prop={'size': 20})


fig = plt.figure(figsize=(15, 15))      
plt.show()

# %% [markdown]
# Визулизируем близость слов друг к другу при помощи t-SNE визуализации

# %%
from sklearn.manifold import TSNE


def tsne_plot(model):
    labels = []
    tokens = []
    
    # Extracting words and their vectors from our trained model 
    for word in model.wv.index_to_key:
        tokens.append(model.wv[word])
        labels.append(word)
    
    # Train t-SNE 
    tsne_model = TSNE(perplexity=45, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(np.array(tokens))
    x = []
    y = []
    
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
        plt.xlabel("dimension 1")
        plt.ylabel("dimension 2")
    plt.show()

tsne_plot(model)

# %% [markdown]
# Поняв, что из этого датасета мы получили мало данных для явной классификации, решаю опробовать предобученную версию word2vec

# %% [markdown]
# Скачаем версию обученнуб на Google News

# %%
import gensim.downloader as api

# takes 3-10 minutes to load
wv = api.load('word2vec-google-news-300')

# %% [markdown]
# Создадим на ее основе эмбеддинги

# %%
embeddings = get_word2vec_embeddings(wv, df)
embeddings = np.array(embeddings)

# %% [markdown]
# Новый график стал более интересным, он плотнее и более информативный

# %%
fig = plt.figure(figsize=(8, 6))         
scatter(y, embeddings)
plt.show()

# %% [markdown]
# Применив к нему PCA получаем новый график, на котором уже явно различаются классы

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings, df['class_label'])

# %%
color_mapper = {label:idx for idx, label in enumerate(set(y))}
color_column = [color_mapper[label] for label in y]
colors = ['pink','blue']


plt.scatter(pca_result[:, 0], pca_result[:, 1], s=8, alpha=.8, c=y, cmap=matplotlib.colors.ListedColormap(colors))
red_patch = mpatches.Patch(color='pink', label='Irrelevant')
green_patch = mpatches.Patch(color='blue', label='Disaster')
plt.legend(handles=[red_patch, green_patch], prop={'size': 20})


fig = plt.figure(figsize=(15, 15))      
plt.show()

# %% [markdown]
# ### Модель с hugging face(Jina AI)

# %% [markdown]
# Скачаем необходимые модули

# %%
# %pip install transformers
# %pip install torch
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/lockr/.local/lib/python3.10/site-packages (4.43.1)
# Requirement already satisfied: filelock in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (3.15.4)
# Requirement already satisfied: safetensors>=0.4.1 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (24.0)
# Requirement already satisfied: requests in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: numpy>=1.17 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (0.24.1)
# Requirement already satisfied: tqdm>=4.27 in /home/lockr/.local/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/lockr/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/lockr/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.8.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lockr/.local/lib/python3.10/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/lockr/.local/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lockr/.local/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lockr/.local/lib/python3.10/site-packages (from requests->transformers) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/lockr/.local/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (4.8.0)
# Requirement already satisfied: fsspec in /home/lockr/.local/lib/python3.10/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: jinja2 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/lockr/.local/lib/python3.10/site-packages (from torch) (2.3.1)
# Requirement already satisfied: filelock in /home/lockr/.local/lib/python3.10/site-packages (from torch) (3.15.4)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch) (1.9)
# Requirement already satisfied: networkx in /home/lockr/.local/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/lockr/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lockr/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Импортируем веса модели из интернета и изменим некоторые гиперпараметры

# %%
from transformers import AutoModel

model = AutoModel.from_pretrained('jinaai/jina-embeddings-v2-base-en', trust_remote_code=True) # trust_remote_code is needed to use the encode method
embeddings = model.encode(df['cleaned_text'],
    max_length=281) #новое ограничение по количеству символов в твитере

# %% [markdown]
# Скачанная модель демонстирует похлжу на word2vec эффективность

# %%
fig = plt.figure(figsize=(8, 6))         
scatter(y, embeddings)
plt.show()

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings, df['class_label'])

# %% [markdown]
# Воспользовашись PCA получаем красивый график, где явно различаются линейно разделимые классы

# %%
color_mapper = {label:idx for idx, label in enumerate(set(y))}
color_column = [color_mapper[label] for label in y]
colors = ['pink','blue']


plt.scatter(pca_result[:, 0], pca_result[:, 1], s=8, alpha=.8, c=y, cmap=matplotlib.colors.ListedColormap(colors))
red_patch = mpatches.Patch(color='pink', label='Irrelevant')
green_patch = mpatches.Patch(color='blue', label='Disaster')
plt.legend(handles=[red_patch, green_patch], prop={'size': 20})


fig = plt.figure(figsize=(15, 15))      
plt.show()
